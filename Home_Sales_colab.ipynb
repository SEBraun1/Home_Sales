# %%
import os
# Find the latest version of spark 3.x  from http://www.apache.org/dist/spark/ and enter as the spark version
# For example:
# spark_version = 'spark-3.3.2'
spark_version = 'spark-3.3.2'
os.environ['SPARK_VERSION']=spark_version

# Install Spark and Java
# !apt-get update
# !apt-get install openjdk-11-jdk-headless -qq > /dev/null
# !wget -q http://www.apache.org/dist/spark/$SPARK_VERSION/$SPARK_VERSION-bin-hadoop3.tgz
# !tar xf $SPARK_VERSION-bin-hadoop3.tgz
# !pip install -q findspark

# Set Environment Variables
os.environ["JAVA_HOME"] = "/usr/lib/jvm/java-11-openjdk-amd64"
os.environ["SPARK_HOME"] = f"/content/{spark_version}-bin-hadoop3"

# Start a SparkSession
import findspark
findspark.init()
# Out:
# Hit:1 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu2004/x86_64  InRelease
# Hit:2 http://security.ubuntu.com/ubuntu focal-security InRelease
# Hit:3 https://cloud.r-project.org/bin/linux/ubuntu focal-cran40/ InRelease
# Hit:4 http://archive.ubuntu.com/ubuntu focal InRelease
# Hit:5 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu focal InRelease
# Hit:6 http://archive.ubuntu.com/ubuntu focal-updates InRelease
# Hit:7 http://archive.ubuntu.com/ubuntu focal-backports InRelease
# Hit:8 http://ppa.launchpad.net/cran/libgit2/ubuntu focal InRelease
# Hit:9 http://ppa.launchpad.net/deadsnakes/ppa/ubuntu focal InRelease
# Hit:10 http://ppa.launchpad.net/graphics-drivers/ppa/ubuntu focal InRelease
# Hit:11 http://ppa.launchpad.net/ubuntugis/ppa/ubuntu focal InRelease
# Reading package lists... Done

# %%
# Import packages
from pyspark.sql import SparkSession
import time

# Create a SparkSession
spark = SparkSession.builder.appName("SparkSQL").getOrCreate()

# %%
# 1. Read in the AWS S3 bucket into a DataFrame.
from pyspark import SparkFiles
url = "https://2u-data-curriculum-team.s3.amazonaws.com/dataviz-classroom/v1.2/22-big-data/home_sales_revised.csv"
spark.sparkContext.addFile(url)
df = spark.read.csv(SparkFiles.get("home_sales_revised.csv"), header=True, inferSchema=True)

# Show DataFrame
df.show()
# Out:
# +--------------------+-------------------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |                  id|               date|date_built| price|bedrooms|bathrooms|sqft_living|sqft_lot|floors|waterfront|view|
# +--------------------+-------------------+----------+------+--------+---------+-----------+--------+------+----------+----+
# |f8a53099-ba1c-47d...|2022-04-08 00:00:00|      2016|936923|       4|        3|       3167|   11733|     2|         1|  76|
# |7530a2d8-1ae3-451...|2021-06-13 00:00:00|      2013|379628|       2|        2|       2235|   14384|     1|         0|  23|
# |43de979c-0bf0-4c9...|2019-04-12 00:00:00|      2014|417866|       2|        2|       2127|   10575|     2|         0|   0|
# |b672c137-b88c-48b...|2019-10-16 00:00:00|      2016|239895|       2|        2|       1631|   11149|     2|         0|   0|
# ...

# %%
# 2. Create a temporary view of the DataFrame.

df.createOrReplaceTempView('homes')

# %%
# 3. What is the average price for a four bedroom house sold in each year rounded to two decimal places?
spark.sql("""
SELECT YEAR(date) as Date,
ROUND(AVG(price), 2) as Avg_Price
FROM homes
WHERE bedrooms=4
GROUP BY 1
ORDER BY 1
""").show()
# Out:
# +----+---------+
# |Date|Avg_Price|
# +----+---------+
# |2019| 300263.7|
# |2020|298353.78|
# |2021|301819.44|
# |2022|296363.88|
# +----+---------+

# %%
# 4. What is the average price of a home for each year the home was built that have 3 bedrooms and 3 bathrooms rounded to two decimal places?
avg_price_built = """
SELECT date_built as Date_Built,
ROUND(AVG(price), 2) as Avg_Price
FROM homes
WHERE bedrooms=3 AND bathrooms=3
GROUP BY 1
ORDER BY 1
"""

avg_price_built_result = spark.sql(avg_price_built)
avg_price_built_result.show()
# Out:
# +----------+---------+
# |Date_Built|Avg_Price|
# +----------+---------+
# |      2010|292859.62|
# |      2011|291117.47|
# |      2012|293683.19|
# |      2013|295962.27|
# |      2014|290852.27|
# |      2015| 288770.3|
# |      2016|290555.07|
# |      2017|292676.79|
# +----------+---------+

# %%
# 5. What is the average price of a home for each year built that have 3 bedrooms, 3 bathrooms, with two floors,
# and are greater than or equal to 2,000 square feet rounded to two decimal places?
avg_price_2000_built = """
SELECT date_built as Date_Built,
ROUND(AVG(price), 2) as Avg_Price
FROM homes
WHERE bedrooms=3 AND bathrooms=3 AND floors = 2 AND sqft_living >= 2000
GROUP BY 1
ORDER BY 1
"""

avg_price_built_2000_result = spark.sql(avg_price_2000_built)
avg_price_built_2000_result.show()
# Out:
# +----------+---------+
# |Date_Built|Avg_Price|
# +----------+---------+
# |      2010|285010.22|
# |      2011|276553.81|
# |      2012|307539.97|
# |      2013|303676.79|
# |      2014|298264.72|
# |      2015|297609.97|
# |      2016| 293965.1|
# |      2017|280317.58|
# +----------+---------+

# %%
# 6. What is the "view" rating for the average price of a home, rounded to two decimal places, where the homes are greater than
# or equal to $350,000? Although this is a small dataset, determine the run time for this query.

start_time = time.time()
view_query = """
SELECT view,
ROUND(AVG(price), 2) as Avg_Price
FROM homes
WHERE price >= 350000
GROUP BY 1
ORDER BY 1
"""

view_result = spark.sql(view_query)
view_result.show()

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+---------+
# |view|Avg_Price|
# +----+---------+
# |   0|403848.51|
# |   1|401044.25|
# |   2|397389.25|
# |   3| 398867.6|
# |   4|399631.89|
# |   5|401471.82|
# |   6|395655.38|
# |   7|403005.77|
# |   8|398592.71|
# |   9|401393.34|
# |  10|401868.43|
# |  11|399548.12|
# |  12|401501.32|
# |  13|398917.98|
# |  14|398570.03|
# |  15| 404673.3|
# |  16|399586.53|
# |  17|398474.49|
# |  18|399332.91|
# |  19|398953.17|
# +----+---------+
# only showing top 20 rows
#
# --- 0.8138995170593262 seconds ---

# %%
# 7. Cache the the temporary table home_sales.
spark.sql("cache table homes")
# Out:
# DataFrame[]

# %%
# 8. Check if the table is cached.
spark.catalog.isCached('homes')
# Out:
# True

# %%
# 9. Using the cached data, run the query that filters out the view ratings with average price 
#  greater than or equal to $350,000. Determine the runtime and compare it to uncached runtime.

start_time = time.time()

avg_price_filter_query = """
SELECT view, 
ROUND(AVG(price), 2) as avg_price
FROM homes
WHERE price < 350000
GROUP BY 1
ORDER BY 1
"""

avg_price_filter_result = spark.sql(avg_price_filter_query)
avg_price_filter_result.show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+---------+
# |view|avg_price|
# +----+---------+
# |   0|238376.66|
# |   1|242193.79|
# |   2|235457.23|
# |   3|234470.83|
# |   4|234796.78|
# |   5|230727.41|
# |   6|233480.09|
# |   7|239960.92|
# |   8|234155.36|
# |   9|236299.02|
# |  10|234761.14|
# |  11|231354.89|
# |  12|233948.16|
# |  13|229736.78|
# |  14|236688.67|
# |  15|236561.03|
# |  16|235060.44|
# |  17|232881.18|
# |  18| 235783.1|
# |  19|233113.02|
# +----+---------+
# only showing top 20 rows
#
# --- 0.6192269325256348 seconds ---

# %%
# 10. Partition by the "date_built" field on the formatted parquet home sales data 
df.write.partitionBy("date_built").mode("overwrite").parquet("homes_parquet")

# %%
# 11. Read the parquet formatted data.
p_homes=spark.read.parquet('homes_parquet')

# %%
# 12. Create a temporary table for the parquet data.
p_homes.createOrReplaceTempView('p_homes_p')

# %%
# 13. Run the query that filters out the view ratings with average price of greater than or equal to $350,000 
# with the parquet DataFrame. Round your average to two decimal places. 
# Determine the runtime and compare it to the cached version.

start_time = time.time()

avg_price_filter_p_query = """
SELECT view, 
ROUND(AVG(price), 2) as avg_price
FROM p_homes_p
WHERE price < 350000
GROUP BY 1
ORDER BY 1
"""

avg_price_filter_p_result = spark.sql(avg_price_filter_p_query)
avg_price_filter_p_result.show()


print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# +----+---------+
# |view|avg_price|
# +----+---------+
# |   0|238376.66|
# |   1|242193.79|
# |   2|235457.23|
# |   3|234470.83|
# |   4|234796.78|
# |   5|230727.41|
# |   6|233480.09|
# |   7|239960.92|
# |   8|234155.36|
# |   9|236299.02|
# |  10|234761.14|
# |  11|231354.89|
# |  12|233948.16|
# |  13|229736.78|
# |  14|236688.67|
# |  15|236561.03|
# |  16|235060.44|
# |  17|232881.18|
# |  18| 235783.1|
# |  19|233113.02|
# +----+---------+
# only showing top 20 rows
#
# --- 0.9262213706970215 seconds ---

# %%
# 14. Uncache the home_sales temporary table.
spark.catalog.uncacheTable("homes")

# %%
# 15. Check if the home_sales is no longer cached
is_cached = spark.catalog.isCached("homes")
print("Is homes table cached? ", is_cached)
# Out:
# Is homes table cached?  False
